# %% [markdown]
# # Healthcare Lab (Advanced Data Filtering)

# %% [markdown]
# **Learning Objectives:**
#   * Practice advanced data filtering over large datasets
#
#   * Gain exposure to healthcare related DataSets

# %% [markdown]
# ## Context of the dataset
#
# ### 1. The dataset is consisted of records corresponding to medical events.
# ### 2. Each medical event is uniquely identified by `MedicalClaim`.
# ### 3. A given medical event might involve several medical procedures.
# ### 4. Each medical procedure is uniquely identified by `ClaimItem`
# ### 5. A given medical procedure is characterized by `PrincipalDiagnosisDesc`,`PrincipalDiagnosis`,`RevenueCodeDesc`, `RevenueCode`, `TypeFlag` and `TotalExpenses`
#
# ### 6. Each medical procedure involves: `MemberName`,`MemberID`,`County`,`HospitalName`, `HospitalType`, `StartDate`,`EndDate`

# %% [markdown]
# ## 1. Library Import

# %%
import pandas as pd
import warnings
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
warnings.simplefilter('ignore')

# %% [markdown]
# ## 2. Data loading and DataFrame creation

# %%
HealthCareDataSet=pd.read_csv("https://github.com/thousandoaks/Python4DS-I/raw/main/datasets/HealthcareDataset_PublicRelease.csv",sep=',',parse_dates=['StartDate','EndDate','BirthDate'])

# %%
HealthCareDataSet.head(3)
# Out:
#        Id MemberName  MemberID    County      MedicalClaim  ClaimItem  \
# 0  634363   e659f3f4  6a380a28  6f943458  c1e3436737c77899         18
# 1  634364   e659f3f4  6a380a28  6f943458  c1e3436737c77899         21
# 2  634387   e659f3f4  6a380a28  6f943458  c1e3436737c77899         10
#
#   HospitalName HospitalType  StartDate    EndDate PrincipalDiagnosisDesc  \
# 0     04b77561     HOSPITAL 2020-01-08 2020-01-08        Epigastric pain
# 1     04b77561     HOSPITAL 2020-01-08 2020-01-08        Epigastric pain
# 2     04b77561     HOSPITAL 2020-01-08 2020-01-08        Epigastric pain
#
#   PrincipalDiagnosis                                    RevenueCodeDesc  \
# 0             R10.13  DRUGS REQUIRE SPECIFIC ID: DRUGS REQUIRING DET...
# 1             R10.13  DRUGS REQUIRE SPECIFIC ID: DRUGS REQUIRING DET...
# 2             R10.13       LABORATORY - CLINICAL DIAGNOSTIC: HEMATOLOGY
#
#    RevenueCode TypeFlag  BirthDate  TotalExpenses
# 0        636.0       ER 1967-05-13         15.148
# 1        636.0       ER 1967-05-13          3.073
# 2        305.0       ER 1967-05-13        123.900

# %%
HealthCareDataSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52563 entries, 0 to 52562
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Id                      52563 non-null  int64
#  1   MemberName              52563 non-null  object
#  2   MemberID                52563 non-null  object
#  3   County                  52563 non-null  object
#  4   MedicalClaim            52563 non-null  object
#  5   ClaimItem               52563 non-null  int64
#  6   HospitalName            52563 non-null  object
#  7   HospitalType            52563 non-null  object
#  8   StartDate               52563 non-null  datetime64[ns]
#  9   EndDate                 52563 non-null  datetime64[ns]
#  10  PrincipalDiagnosisDesc  52563 non-null  object
#  11  PrincipalDiagnosis      52563 non-null  object
#  12  RevenueCodeDesc         52561 non-null  object
#  13  RevenueCode             52563 non-null  float64
#  14  TypeFlag                52563 non-null  object
#  15  BirthDate               52563 non-null  datetime64[ns]
#  16  TotalExpenses           52563 non-null  float64
# dtypes: datetime64[ns](3), float64(2), int64(2), object(10)
# memory usage: 6.8+ MB

# %% [markdown]
# ## Let's select events which took place in county `6f943458` between 2020-01-01 and 2020-03-30

# %%
HealthCareDataSet[(HealthCareDataSet['County']=='6f943458')&(HealthCareDataSet['StartDate']>='2020-01-01')&(HealthCareDataSet['StartDate']<='2020-03-30')]
# Out:
#            Id MemberName  MemberID    County      MedicalClaim  ClaimItem  \
# 0      634363   e659f3f4  6a380a28  6f943458  c1e3436737c77899         18
# 1      634364   e659f3f4  6a380a28  6f943458  c1e3436737c77899         21
# 2      634387   e659f3f4  6a380a28  6f943458  c1e3436737c77899         10
# 3      634388   e659f3f4  6a380a28  6f943458  c1e3436737c77899         20
# 4      634389   e659f3f4  6a380a28  6f943458  c1e3436737c77899         19
# ...       ...        ...       ...       ...               ...        ...
# 15200  662533   44a22f0a  b45a0316  6f943458  e864eeda054bdd64         14
# 15201  662542   51c1b3b3  a0d2f73a  6f943458  819b06ce1c775016          1
# 15202  662543   51c1b3b3  a0d2f73a  6f943458  819b06ce1c775016          4
# 15203  662544   51c1b3b3  a0d2f73a  6f943458  819b06ce1c775016          2
# 15204  662546   51c1b3b3  a0d2f73a  6f943458  819b06ce1c775016          3
#
#       HospitalName HospitalType  StartDate    EndDate PrincipalDiagnosisDesc  \
# 0         04b77561     HOSPITAL 2020-01-08 2020-01-08        Epigastric pain
# 1         04b77561     HOSPITAL 2020-01-08 2020-01-08        Epigastric pain
# 2         04b77561     HOSPITAL 2020-01-08 2020-01-08        Epigastric pain
# 3         04b77561     HOSPITAL 2020-01-08 2020-01-08        Epigastric pain
# 4         04b77561     HOSPITAL 2020-01-08 2020-01-08        Epigastric pain
# ...            ...          ...        ...        ...                    ...
# 15200     04b77561     HOSPITAL 2020-03-30 2020-03-30               Headache
# 15201     04b77561     HOSPITAL 2020-03-28 2020-03-28        Fecal impaction
# 15202     04b77561     HOSPITAL 2020-03-28 2020-03-28        Fecal impaction
# 15203     04b77561     HOSPITAL 2020-03-28 2020-03-28        Fecal impaction
# 15204     04b77561     HOSPITAL 2020-03-28 2020-03-28        Fecal impaction
#
#       PrincipalDiagnosis                                    RevenueCodeDesc  \
# 0                 R10.13  DRUGS REQUIRE SPECIFIC ID: DRUGS REQUIRING DET...
# 1                 R10.13  DRUGS REQUIRE SPECIFIC ID: DRUGS REQUIRING DET...
# 2                 R10.13       LABORATORY - CLINICAL DIAGNOSTIC: HEMATOLOGY
# 3                 R10.13  DRUGS REQUIRE SPECIFIC ID: DRUGS REQUIRING DET...
# 4                 R10.13  DRUGS REQUIRE SPECIFIC ID: DRUGS REQUIRING DET...
# ...                  ...                                                ...
# 15200                R51  DRUGS REQUIRE SPECIFIC ID: DRUGS REQUIRING DET...
# 15201             K56.41        LABORATORY - CLINICAL DIAGNOSTIC: CHEMISTRY
# 15202             K56.41                                     EMERGENCY ROOM
# 15203             K56.41       LABORATORY - CLINICAL DIAGNOSTIC: HEMATOLOGY
# 15204             K56.41                                            CT SCAN
#
#        RevenueCode TypeFlag  BirthDate  TotalExpenses
# 0            636.0       ER 1967-05-13         15.148
# 1            636.0       ER 1967-05-13          3.073
# 2            305.0       ER 1967-05-13        123.900
# 3            636.0       ER 1967-05-13          7.511
# 4            636.0       ER 1967-05-13          8.631
# ...            ...      ...        ...            ...
# 15200        636.0       ER 1963-03-08          3.073
# 15201        301.0       ER 1937-08-31        199.500
# 15202        450.0       ER 1937-08-31       3549.700
# 15203        305.0       ER 1937-08-31        145.600
# 15204        350.0       ER 1937-08-31       5597.200
#
# [623 rows x 17 columns]

# %% [markdown]
# ## Let's select events belonging to the medical categories J00-J06 (Acute upper respiratory infections)
#
# https://www.icd10data.com/ICD10CM/Codes/J00-J99/J00-J06

# %%
## We need to extract medical events having PrincipalDiagnosis starting with J00 up to J06
HealthCareDataSet['PrincipalDiagnosis_First_Term']=HealthCareDataSet['PrincipalDiagnosis'].apply(lambda x:x[0:3])
HealthCareDataSet[['PrincipalDiagnosis','PrincipalDiagnosis_First_Term']]
# Out:
#       PrincipalDiagnosis PrincipalDiagnosis_First_Term
# 0                 R10.13                           R10
# 1                 R10.13                           R10
# 2                 R10.13                           R10
# 3                 R10.13                           R10
# 4                 R10.13                           R10
# ...                  ...                           ...
# 52558           S06.6X0A                           S06
# 52559              D50.0                           D50
# 52560              D50.0                           D50
# 52561              D50.0                           D50
# 52562              D50.0                           D50
#
# [52563 rows x 2 columns]

# %%
#Create a list of diagnosis codes to filter by
diagnosis_codes = ['J00', 'J01', 'J02', 'J03', 'J04', 'J05', 'J06']

# %%
HealthCareDataSet[HealthCareDataSet['PrincipalDiagnosis_First_Term'].isin(diagnosis_codes)]
# Out:
#            Id MemberName  MemberID    County      MedicalClaim  ClaimItem  \
# 1308   636302   2180e78a  911f3fa9  39825de7  851f538783239953          1
# 4541   642351   9e60a4d2  16d3c58c  ea48569b  760a0ebcf220f307          6
# 4542   642352   9e60a4d2  16d3c58c  ea48569b  760a0ebcf220f307          1
# 4543   642353   9e60a4d2  16d3c58c  ea48569b  760a0ebcf220f307          2
# 4544   642354   9e60a4d2  16d3c58c  ea48569b  760a0ebcf220f307          4
# ...       ...        ...       ...       ...               ...        ...
# 50347  736314   04778840  029a89fd  02af982d  aa31c80e8aa40256          4
# 50348  736315   04778840  029a89fd  02af982d  aa31c80e8aa40256          5
# 52024  740425   11b84dfc  74942b26  6f943458  0c15f2cfdc372119          2
# 52025  740427   11b84dfc  74942b26  6f943458  0c15f2cfdc372119          3
# 52026  740428   11b84dfc  74942b26  6f943458  0c15f2cfdc372119          1
#
#       HospitalName HospitalType  StartDate    EndDate  \
# 1308      13dda4ec     HOSPITAL 2020-01-23 2020-01-23
# 4541      761ae146     HOSPITAL 2020-01-26 2020-01-26
# 4542      761ae146     HOSPITAL 2020-01-26 2020-01-26
# 4543      761ae146     HOSPITAL 2020-01-26 2020-01-26
# 4544      761ae146     HOSPITAL 2020-01-26 2020-01-26
# ...            ...          ...        ...        ...
# 50347     4d103af0     HOSPITAL 2020-12-13 2020-12-13
# 50348     4d103af0     HOSPITAL 2020-12-13 2020-12-13
# 52024     f0b2e1c6     HOSPITAL 2020-12-21 2020-12-21
# 52025     f0b2e1c6     HOSPITAL 2020-12-21 2020-12-21
# 52026     f0b2e1c6     HOSPITAL 2020-12-21 2020-12-21
#
#           PrincipalDiagnosisDesc PrincipalDiagnosis  \
# 1308   Acute pharyngitis unspeci              J02.9
# 4541   Acute upper respiratory i              J06.9
# 4542   Acute upper respiratory i              J06.9
# 4543   Acute upper respiratory i              J06.9
# 4544   Acute upper respiratory i              J06.9
# ...                          ...                ...
# 50347  Streptococcal pharyngitis              J02.0
# 50348  Streptococcal pharyngitis              J02.0
# 52024  Acute upper respiratory i              J06.9
# 52025  Acute upper respiratory i              J06.9
# 52026  Acute upper respiratory i              J06.9
#
#                                          RevenueCodeDesc  RevenueCode  \
# 1308                                      EMERGENCY ROOM        450.0
# 4541                                      EMERGENCY ROOM        450.0
# 4542                                   PHARMACY: GENERIC        251.0
# 4543         LABORATORY - CLINICAL DIAGNOSTIC: CHEMISTRY        301.0
# 4544   LABORATORY - CLINICAL DIAGNOSTIC: BACTERIOLOGY...        306.0
# ...                                                  ...          ...
# 50347                                     EMERGENCY ROOM        450.0
# 50348  DRUGS REQUIRE SPECIFIC ID: DRUGS REQUIRING DET...        636.0
# 52024  LABORATORY - CLINICAL DIAGNOSTIC: BACTERIOLOGY...        306.0
# 52025                                     EMERGENCY ROOM        450.0
# 52026        MEDICAL/SURGICAL SUPPLIES: STERILE SUPPLIES        272.0
#
#       TypeFlag  BirthDate  TotalExpenses PrincipalDiagnosis_First_Term
# 1308        ER 1952-12-14       1092.000                           J02
# 4541        ER 1937-03-07       1076.278                           J06
# 4542        ER 1937-03-07          5.614                           J06
# 4543        ER 1937-03-07         64.295                           J06
# 4544        ER 1937-03-07         46.760                           J06
# ...        ...        ...            ...                           ...
# 50347       ER 1977-09-19        142.338                           J02
# 50348       ER 1977-09-19       1667.526                           J02
# 52024       ER 1947-06-15         37.100                           J06
# 52025       ER 1947-06-15       2181.900                           J06
# 52026       ER 1947-06-15         31.591                           J06
#
# [255 rows x 18 columns]

# %% [markdown]
# ## Let's change the Id of the member '16d3c58c' to '999999'

# %%
HealthCareDataSet.loc[HealthCareDataSet['MemberID']=='16d3c58c','MemberID']='999999'
# Out:
#            Id MemberName  MemberID    County      MedicalClaim  ClaimItem  \
# 0      634363   e659f3f4  6a380a28  6f943458  c1e3436737c77899         18
# 1      634364   e659f3f4  6a380a28  6f943458  c1e3436737c77899         21
# 2      634387   e659f3f4  6a380a28  6f943458  c1e3436737c77899         10
# 3      634388   e659f3f4  6a380a28  6f943458  c1e3436737c77899         20
# 4      634389   e659f3f4  6a380a28  6f943458  c1e3436737c77899         19
# ...       ...        ...       ...       ...               ...        ...
# 52558  741726   ff90a52f  4ed7db9f  425a37b2  90e8ae169cbba3bd          1
# 52559  741733   f90fcde2  c88e4212  425a37b2  8b6a8d2720d16e97          7
# 52560  741734   f90fcde2  c88e4212  425a37b2  8b6a8d2720d16e97          8
# 52561  741735   f90fcde2  c88e4212  425a37b2  8b6a8d2720d16e97         12
# 52562  741736   f90fcde2  c88e4212  425a37b2  8b6a8d2720d16e97          5
#
#       HospitalName HospitalType  StartDate    EndDate  \
# 0         04b77561     HOSPITAL 2020-01-08 2020-01-08
# 1         04b77561     HOSPITAL 2020-01-08 2020-01-08
# 2         04b77561     HOSPITAL 2020-01-08 2020-01-08
# 3         04b77561     HOSPITAL 2020-01-08 2020-01-08
# 4         04b77561     HOSPITAL 2020-01-08 2020-01-08
# ...            ...          ...        ...        ...
# 52558     a9bf1474     HOSPITAL 2020-12-02 2020-12-09
# 52559     a9bf1474     HOSPITAL 2020-12-18 2020-12-22
# 52560     a9bf1474     HOSPITAL 2020-12-18 2020-12-22
# 52561     a9bf1474     HOSPITAL 2020-12-18 2020-12-22
# 52562     a9bf1474     HOSPITAL 2020-12-18 2020-12-22
#
#           PrincipalDiagnosisDesc PrincipalDiagnosis  \
# 0                Epigastric pain             R10.13
# 1                Epigastric pain             R10.13
# 2                Epigastric pain             R10.13
# 3                Epigastric pain             R10.13
# 4                Epigastric pain             R10.13
# ...                          ...                ...
# 52558  Traumatic subarachnoid he           S06.6X0A
# 52559  Iron deficiency anemia se              D50.0
# 52560  Iron deficiency anemia se              D50.0
# 52561  Iron deficiency anemia se              D50.0
# 52562  Iron deficiency anemia se              D50.0
#
#                                          RevenueCodeDesc  RevenueCode  \
# 0      DRUGS REQUIRE SPECIFIC ID: DRUGS REQUIRING DET...        636.0
# 1      DRUGS REQUIRE SPECIFIC ID: DRUGS REQUIRING DET...        636.0
# 2           LABORATORY - CLINICAL DIAGNOSTIC: HEMATOLOGY        305.0
# 3      DRUGS REQUIRE SPECIFIC ID: DRUGS REQUIRING DET...        636.0
# 4      DRUGS REQUIRE SPECIFIC ID: DRUGS REQUIRING DET...        636.0
# ...                                                  ...          ...
# 52558                                   INTERMEDIATE ICU        206.0
# 52559       LABORATORY - CLINICAL DIAGNOSTIC: HEMATOLOGY        305.0
# 52560                RADIOLOGY - DIAGNOSTIC: CHEST X-RAY        324.0
# 52561                                            EKG/ECG        730.0
# 52562        LABORATORY - CLINICAL DIAGNOSTIC: CHEMISTRY        301.0
#
#       TypeFlag  BirthDate  TotalExpenses PrincipalDiagnosis_First_Term
# 0           ER 1967-05-13         15.148                           R10
# 1           ER 1967-05-13          3.073                           R10
# 2           ER 1967-05-13        123.900                           R10
# 3           ER 1967-05-13          7.511                           R10
# 4           ER 1967-05-13          8.631                           R10
# ...        ...        ...            ...                           ...
# 52558      INP 1940-04-13       2436.000                           S06
# 52559      INP 1950-09-15       2075.500                           D50
# 52560      INP 1950-09-15        865.900                           D50
# 52561      INP 1950-09-15        665.000                           D50
# 52562      INP 1950-09-15       4587.800                           D50
#
# [52563 rows x 18 columns]

# %% [markdown]
# ## Let's change the name of the member '999999' to 'Thomas Mann'

# %%
HealthCareDataSet.loc[HealthCareDataSet['MemberID']=='999999','MemberName']='Thomas Mann'

# %%
HealthCareDataSet[HealthCareDataSet['MemberName']=='Thomas Mann']
# Out:
#           Id   MemberName MemberID    County      MedicalClaim  ClaimItem  \
# 4541  642351  Thomas Mann   999999  ea48569b  760a0ebcf220f307          6
# 4542  642352  Thomas Mann   999999  ea48569b  760a0ebcf220f307          1
# 4543  642353  Thomas Mann   999999  ea48569b  760a0ebcf220f307          2
# 4544  642354  Thomas Mann   999999  ea48569b  760a0ebcf220f307          4
# 5085  643871  Thomas Mann   999999  ea48569b  760a0ebcf220f307          5
# 5177  644064  Thomas Mann   999999  ea48569b  760a0ebcf220f307          3
#
#      HospitalName HospitalType  StartDate    EndDate  \
# 4541     761ae146     HOSPITAL 2020-01-26 2020-01-26
# 4542     761ae146     HOSPITAL 2020-01-26 2020-01-26
# 4543     761ae146     HOSPITAL 2020-01-26 2020-01-26
# 4544     761ae146     HOSPITAL 2020-01-26 2020-01-26
# 5085     761ae146     HOSPITAL 2020-01-26 2020-01-26
# 5177     761ae146     HOSPITAL 2020-01-26 2020-01-26
#
#          PrincipalDiagnosisDesc PrincipalDiagnosis  \
# 4541  Acute upper respiratory i              J06.9
# 4542  Acute upper respiratory i              J06.9
# 4543  Acute upper respiratory i              J06.9
# 4544  Acute upper respiratory i              J06.9
# 5085  Acute upper respiratory i              J06.9
# 5177  Acute upper respiratory i              J06.9
#
#                                         RevenueCodeDesc  RevenueCode TypeFlag  \
# 4541                                     EMERGENCY ROOM        450.0       ER
# 4542                                  PHARMACY: GENERIC        251.0       ER
# 4543        LABORATORY - CLINICAL DIAGNOSTIC: CHEMISTRY        301.0       ER
# 4544  LABORATORY - CLINICAL DIAGNOSTIC: BACTERIOLOGY...        306.0       ER
# 5085                RADIOLOGY - DIAGNOSTIC: CHEST X-RAY        324.0       ER
# 5177       LABORATORY - CLINICAL DIAGNOSTIC: HEMATOLOGY        305.0       ER
#
#       BirthDate  TotalExpenses PrincipalDiagnosis_First_Term
# 4541 1937-03-07       1076.278                           J06
# 4542 1937-03-07          5.614                           J06
# 4543 1937-03-07         64.295                           J06
# 4544 1937-03-07         46.760                           J06
# 5085 1937-03-07        156.352                           J06
# 5177 1937-03-07         40.915                           J06
