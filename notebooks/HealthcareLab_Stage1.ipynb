# %% [markdown]
# # Healthcare Lab (Stage 1)

# %% [markdown]
# **Learning Objectives:**
#   * Practice basic data manipulation with Pandas
#   * Gain exposure to healthcare related DataSets

# %% [markdown]
# ## Context of the dataset
#
# ### 1. The dataset is consisted of records corresponding to medical events.
# ### 2. Each medical event is uniquely identified by `MedicalClaim`.
# ### 3. A given medical event might involve several medical procedures.
# ### 4. Each medical procedure is uniquely identified by `ClaimItem`
# ### 5. A given medical procedure is characterized by `PrincipalDiagnosisDesc`,`PrincipalDiagnosis`,`RevenueCodeDesc`, `RevenueCode`, `TypeFlag` and `TotalExpenses`
#
# ### 6. Each medical procedure involves: `MemberName`,`MemberID`,`County`,`HospitalName`, `HospitalType`, `StartDate`,`EndDate`

# %% [markdown]
# ## 1. Library Import

# %%
import pandas as pd
import warnings
import numpy as np

# %%
warnings.simplefilter('ignore')

# %% [markdown]
# ## 2. Data loading and DataFrame creation

# %%
HealthCareDataSet=pd.read_csv("https://github.com/thousandoaks/Python4DS-I/raw/main/datasets/HealthcareDataset_PublicRelease.csv",sep=',',parse_dates=['StartDate','EndDate','BirthDate'])

# %%
HealthCareDataSet.head(3)
# Out:
#        Id MemberName  MemberID    County      MedicalClaim  ClaimItem  \
# 0  634363   e659f3f4  6a380a28  6f943458  c1e3436737c77899         18
# 1  634364   e659f3f4  6a380a28  6f943458  c1e3436737c77899         21
# 2  634387   e659f3f4  6a380a28  6f943458  c1e3436737c77899         10
#
#   HospitalName HospitalType  StartDate    EndDate PrincipalDiagnosisDesc  \
# 0     04b77561     HOSPITAL 2020-01-08 2020-01-08        Epigastric pain
# 1     04b77561     HOSPITAL 2020-01-08 2020-01-08        Epigastric pain
# 2     04b77561     HOSPITAL 2020-01-08 2020-01-08        Epigastric pain
#
#   PrincipalDiagnosis                                    RevenueCodeDesc  \
# 0             R10.13  DRUGS REQUIRE SPECIFIC ID: DRUGS REQUIRING DET...
# 1             R10.13  DRUGS REQUIRE SPECIFIC ID: DRUGS REQUIRING DET...
# 2             R10.13       LABORATORY - CLINICAL DIAGNOSTIC: HEMATOLOGY
#
#    RevenueCode TypeFlag  BirthDate  TotalExpenses
# 0        636.0       ER 1967-05-13         15.148
# 1        636.0       ER 1967-05-13          3.073
# 2        305.0       ER 1967-05-13        123.900

# %%
HealthCareDataSet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52563 entries, 0 to 52562
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Id                      52563 non-null  int64
#  1   MemberName              52563 non-null  object
#  2   MemberID                52563 non-null  object
#  3   County                  52563 non-null  object
#  4   MedicalClaim            52563 non-null  object
#  5   ClaimItem               52563 non-null  int64
#  6   HospitalName            52563 non-null  object
#  7   HospitalType            52563 non-null  object
#  8   StartDate               52563 non-null  datetime64[ns]
#  9   EndDate                 52563 non-null  datetime64[ns]
#  10  PrincipalDiagnosisDesc  52563 non-null  object
#  11  PrincipalDiagnosis      52563 non-null  object
#  12  RevenueCodeDesc         52561 non-null  object
#  13  RevenueCode             52563 non-null  float64
#  14  TypeFlag                52563 non-null  object
#  15  BirthDate               52563 non-null  datetime64[ns]
#  16  TotalExpenses           52563 non-null  float64
# dtypes: datetime64[ns](3), float64(2), int64(2), object(10)
# memory usage: 6.8+ MB

# %% [markdown]
# ## 3. Column Selection

# %%
HealthCareDataSet[['MemberName','MedicalClaim','ClaimItem','TotalExpenses']]
# Out:
#       MemberName      MedicalClaim  ClaimItem  TotalExpenses
# 0       e659f3f4  c1e3436737c77899         18         15.148
# 1       e659f3f4  c1e3436737c77899         21          3.073
# 2       e659f3f4  c1e3436737c77899         10        123.900
# 3       e659f3f4  c1e3436737c77899         20          7.511
# 4       e659f3f4  c1e3436737c77899         19          8.631
# ...          ...               ...        ...            ...
# 52558   ff90a52f  90e8ae169cbba3bd          1       2436.000
# 52559   f90fcde2  8b6a8d2720d16e97          7       2075.500
# 52560   f90fcde2  8b6a8d2720d16e97          8        865.900
# 52561   f90fcde2  8b6a8d2720d16e97         12        665.000
# 52562   f90fcde2  8b6a8d2720d16e97          5       4587.800
#
# [52563 rows x 4 columns]

# %%
ReducedDataSet=HealthCareDataSet[['MemberName','MedicalClaim','ClaimItem','BirthDate','TotalExpenses']]

# %%
ReducedDataSet.head()
# Out:
#   MemberName      MedicalClaim  ClaimItem  BirthDate  TotalExpenses
# 0   e659f3f4  c1e3436737c77899         18 1967-05-13         15.148
# 1   e659f3f4  c1e3436737c77899         21 1967-05-13          3.073
# 2   e659f3f4  c1e3436737c77899         10 1967-05-13        123.900
# 3   e659f3f4  c1e3436737c77899         20 1967-05-13          7.511
# 4   e659f3f4  c1e3436737c77899         19 1967-05-13          8.631

# %% [markdown]
# ## 4. Column Elimination

# %%
## we set axis=1 to instruct Pandas to drop on a column basis.
ReducedDataSetNoBirthDate=ReducedDataSet.drop('BirthDate',axis=1)

# %%
ReducedDataSetNoBirthDate
# Out:
#       MemberName      MedicalClaim  ClaimItem  TotalExpenses
# 0       e659f3f4  c1e3436737c77899         18         15.148
# 1       e659f3f4  c1e3436737c77899         21          3.073
# 2       e659f3f4  c1e3436737c77899         10        123.900
# 3       e659f3f4  c1e3436737c77899         20          7.511
# 4       e659f3f4  c1e3436737c77899         19          8.631
# ...          ...               ...        ...            ...
# 52558   ff90a52f  90e8ae169cbba3bd          1       2436.000
# 52559   f90fcde2  8b6a8d2720d16e97          7       2075.500
# 52560   f90fcde2  8b6a8d2720d16e97          8        865.900
# 52561   f90fcde2  8b6a8d2720d16e97         12        665.000
# 52562   f90fcde2  8b6a8d2720d16e97          5       4587.800
#
# [52563 rows x 4 columns]

# %%
pd.set_option('mode.chained_assignment', None)

# %%
# By default pandas operations DO NOT affect the original dataframe, you need to set inplace=True to write over the original dataframe
ReducedDataSet.drop('BirthDate',axis=1,inplace=True)

# %%
ReducedDataSet
# Out:
#       MemberName      MedicalClaim  ClaimItem  TotalExpenses
# 0       e659f3f4  c1e3436737c77899         18         15.148
# 1       e659f3f4  c1e3436737c77899         21          3.073
# 2       e659f3f4  c1e3436737c77899         10        123.900
# 3       e659f3f4  c1e3436737c77899         20          7.511
# 4       e659f3f4  c1e3436737c77899         19          8.631
# ...          ...               ...        ...            ...
# 52558   ff90a52f  90e8ae169cbba3bd          1       2436.000
# 52559   f90fcde2  8b6a8d2720d16e97          7       2075.500
# 52560   f90fcde2  8b6a8d2720d16e97          8        865.900
# 52561   f90fcde2  8b6a8d2720d16e97         12        665.000
# 52562   f90fcde2  8b6a8d2720d16e97          5       4587.800
#
# [52563 rows x 4 columns]

# %% [markdown]
# ## 5. Column Renaming

# %%
ReducedDataSet.rename(columns={"MemberName":"NameID","TotalExpenses":"OverallExpenses"},inplace=True)

# %%
ReducedDataSet
# Out:
#          NameID      MedicalClaim  ClaimItem  OverallExpenses
# 0      e659f3f4  c1e3436737c77899         18           15.148
# 1      e659f3f4  c1e3436737c77899         21            3.073
# 2      e659f3f4  c1e3436737c77899         10          123.900
# 3      e659f3f4  c1e3436737c77899         20            7.511
# 4      e659f3f4  c1e3436737c77899         19            8.631
# ...         ...               ...        ...              ...
# 52558  ff90a52f  90e8ae169cbba3bd          1         2436.000
# 52559  f90fcde2  8b6a8d2720d16e97          7         2075.500
# 52560  f90fcde2  8b6a8d2720d16e97          8          865.900
# 52561  f90fcde2  8b6a8d2720d16e97         12          665.000
# 52562  f90fcde2  8b6a8d2720d16e97          5         4587.800
#
# [52563 rows x 4 columns]

# %% [markdown]
# ## 6. Operations on Columns

# %%
ReducedDataSet['OverallExpensesPowered']=ReducedDataSet['OverallExpenses']**2

# %%
ReducedDataSet
# Out:
#          NameID      MedicalClaim  ClaimItem  OverallExpenses  \
# 0      e659f3f4  c1e3436737c77899         18           15.148
# 1      e659f3f4  c1e3436737c77899         21            3.073
# 2      e659f3f4  c1e3436737c77899         10          123.900
# 3      e659f3f4  c1e3436737c77899         20            7.511
# 4      e659f3f4  c1e3436737c77899         19            8.631
# ...         ...               ...        ...              ...
# 52558  ff90a52f  90e8ae169cbba3bd          1         2436.000
# 52559  f90fcde2  8b6a8d2720d16e97          7         2075.500
# 52560  f90fcde2  8b6a8d2720d16e97          8          865.900
# 52561  f90fcde2  8b6a8d2720d16e97         12          665.000
# 52562  f90fcde2  8b6a8d2720d16e97          5         4587.800
#
#        OverallExpensesPowered
# 0                2.294619e+02
# 1                9.443329e+00
# 2                1.535121e+04
# 3                5.641512e+01
# 4                7.449416e+01
# ...                       ...
# 52558            5.934096e+06
# 52559            4.307700e+06
# 52560            7.497828e+05
# 52561            4.422250e+05
# 52562            2.104791e+07
#
# [52563 rows x 5 columns]

# %%
ReducedDataSet['OverallExpensesLog']=np.log(ReducedDataSet['OverallExpenses'])

# %%
ReducedDataSet
# Out:
#          NameID      MedicalClaim  ClaimItem  OverallExpenses  \
# 0      e659f3f4  c1e3436737c77899         18           15.148
# 1      e659f3f4  c1e3436737c77899         21            3.073
# 2      e659f3f4  c1e3436737c77899         10          123.900
# 3      e659f3f4  c1e3436737c77899         20            7.511
# 4      e659f3f4  c1e3436737c77899         19            8.631
# ...         ...               ...        ...              ...
# 52558  ff90a52f  90e8ae169cbba3bd          1         2436.000
# 52559  f90fcde2  8b6a8d2720d16e97          7         2075.500
# 52560  f90fcde2  8b6a8d2720d16e97          8          865.900
# 52561  f90fcde2  8b6a8d2720d16e97         12          665.000
# 52562  f90fcde2  8b6a8d2720d16e97          5         4587.800
#
#        OverallExpensesPowered  OverallExpensesLog
# 0                2.294619e+02            2.717869
# 1                9.443329e+00            1.122654
# 2                1.535121e+04            4.819475
# 3                5.641512e+01            2.016369
# 4                7.449416e+01            2.155360
# ...                       ...                 ...
# 52558            5.934096e+06            7.798113
# 52559            4.307700e+06            7.637957
# 52560            7.497828e+05            6.763769
# 52561            4.422250e+05            6.499787
# 52562            2.104791e+07            8.431156
#
# [52563 rows x 6 columns]

# %% [markdown]
# ## 7. Groupby Operations

# %% [markdown]
# ### Let's compute the average expenses accross counties
# #### For this we need to perform a groupby operation. We groupby on `County` and compute the mean of `TotalExpenses`

# %%
HealthCareDataSet.head(3)
# Out:
#        Id MemberName  MemberID    County      MedicalClaim  ClaimItem  \
# 0  634363   e659f3f4  6a380a28  6f943458  c1e3436737c77899         18
# 1  634364   e659f3f4  6a380a28  6f943458  c1e3436737c77899         21
# 2  634387   e659f3f4  6a380a28  6f943458  c1e3436737c77899         10
#
#   HospitalName HospitalType  StartDate    EndDate PrincipalDiagnosisDesc  \
# 0     04b77561     HOSPITAL 2020-01-08 2020-01-08        Epigastric pain
# 1     04b77561     HOSPITAL 2020-01-08 2020-01-08        Epigastric pain
# 2     04b77561     HOSPITAL 2020-01-08 2020-01-08        Epigastric pain
#
#   PrincipalDiagnosis                                    RevenueCodeDesc  \
# 0             R10.13  DRUGS REQUIRE SPECIFIC ID: DRUGS REQUIRING DET...
# 1             R10.13  DRUGS REQUIRE SPECIFIC ID: DRUGS REQUIRING DET...
# 2             R10.13       LABORATORY - CLINICAL DIAGNOSTIC: HEMATOLOGY
#
#    RevenueCode TypeFlag  BirthDate  TotalExpenses
# 0        636.0       ER 1967-05-13         15.148
# 1        636.0       ER 1967-05-13          3.073
# 2        305.0       ER 1967-05-13        123.900

# %%
HealthCareDataSet.groupby(['County'])['TotalExpenses'].mean()
# Out:
# County
# 02af982d    2961.022264
# 217dc01f     531.107559
# 33b7d74d    1733.242000
# 39825de7    1863.681612
# 425a37b2    2523.756193
# 5597ffc0    1552.266828
# 6f0b5b6c    2507.675586
# 6f943458    3209.269318
# 7a56b047     488.600000
# 7d9b432e    2756.528070
# 89e38653    2349.649500
# adb3fb00    2823.448197
# b021dd12    2249.052194
# b60a20c4    1666.055741
# bd284e56     964.693333
# e6708950    2626.775110
# ea48569b    1183.120767
# fc471384    2790.097970
# fd218584    3068.508123
# Name: TotalExpenses, dtype: float64

# %% [markdown]
# ### Let's compute the average expenses accross types of medical events
# #### For this we need to perform a groupby operation. We groupby on `TypeFlag` and compute the mean of `TotalExpenses`

# %%
HealthCareDataSet.groupby(['TypeFlag'])['TotalExpenses'].mean()
# Out:
# TypeFlag
# ER      923.916490
# INP    4254.617614
# Name: TotalExpenses, dtype: float64

# %% [markdown]
# ### Let's compute the average expenses accross counties AND types of medical events
# #### For this we need to perform a groupby operation. We groupby on `County` AND `TypeFlag` and compute the mean of `TotalExpenses`

# %%
HealthCareDataSet.groupby(['County','TypeFlag'])['TotalExpenses'].mean()
# Out:
# County    TypeFlag
# 02af982d  ER          1095.624231
#           INP         4182.315427
# 217dc01f  ER           269.906778
#           INP         1370.681500
# 33b7d74d  ER          1733.242000
# 39825de7  ER           964.264615
#           INP         2969.721432
# 425a37b2  ER           734.935974
#           INP         4716.259394
# 5597ffc0  ER           396.251544
#           INP         5569.128020
# 6f0b5b6c  ER           787.870467
#           INP         3554.513484
# 6f943458  ER           754.605412
#           INP         4832.479233
# 7a56b047  ER           488.600000
# 7d9b432e  ER          1024.500420
#           INP         3998.761016
# 89e38653  ER           950.906526
#           INP         4032.230959
# adb3fb00  ER          1088.552277
#           INP         3847.806539
# b021dd12  ER           754.865066
#           INP         3589.799426
# b60a20c4  ER           390.176182
#           INP         2543.222938
# bd284e56  ER           964.693333
# e6708950  ER           714.899357
#           INP         4223.267490
# ea48569b  ER           453.356873
#           INP         1913.953129
# fc471384  ER          1070.826991
#           INP         5680.466572
# fd218584  ER          1040.453367
#           INP         4846.791924
# Name: TotalExpenses, dtype: float64

# %% [markdown]
# ### Let's compute the average expenses accross types of hospitals
# #### For this we need to perform a groupby operation. We groupby on `HospitalType` and compute the mean of `TotalExpenses`

# %%
HealthCareDataSet.groupby(['HospitalType'])['TotalExpenses'].mean()
# Out:
# HospitalType
# HOSPITAL                    2732.788708
# HOSPITAL LONG TERM ACUTE    5411.281424
# REHABILITATION CENTER       1248.298100
# Name: TotalExpenses, dtype: float64

# %% [markdown]
# ## 8. Filtering Operations

# %% [markdown]
# ### Let's select Emergency Room Services related events
# #### For this we need to perform a filtering operation. We filter on the columm `TypeFlag`.

# %%
HealthCareDataSet.head(3)
# Out:
#        Id MemberName  MemberID    County      MedicalClaim  ClaimItem  \
# 0  634363   e659f3f4  6a380a28  6f943458  c1e3436737c77899         18
# 1  634364   e659f3f4  6a380a28  6f943458  c1e3436737c77899         21
# 2  634387   e659f3f4  6a380a28  6f943458  c1e3436737c77899         10
#
#   HospitalName HospitalType  StartDate    EndDate PrincipalDiagnosisDesc  \
# 0     04b77561     HOSPITAL 2020-01-08 2020-01-08        Epigastric pain
# 1     04b77561     HOSPITAL 2020-01-08 2020-01-08        Epigastric pain
# 2     04b77561     HOSPITAL 2020-01-08 2020-01-08        Epigastric pain
#
#   PrincipalDiagnosis                                    RevenueCodeDesc  \
# 0             R10.13  DRUGS REQUIRE SPECIFIC ID: DRUGS REQUIRING DET...
# 1             R10.13  DRUGS REQUIRE SPECIFIC ID: DRUGS REQUIRING DET...
# 2             R10.13       LABORATORY - CLINICAL DIAGNOSTIC: HEMATOLOGY
#
#    RevenueCode TypeFlag  BirthDate  TotalExpenses
# 0        636.0       ER 1967-05-13         15.148
# 1        636.0       ER 1967-05-13          3.073
# 2        305.0       ER 1967-05-13        123.900

# %%
## We define the filter

HealthCareDataSet['TypeFlag']=='ER'
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 52558    False
# 52559    False
# 52560    False
# 52561    False
# 52562    False
# Name: TypeFlag, Length: 52563, dtype: bool

# %%
## We save the filter

ERFilter=HealthCareDataSet['TypeFlag']=='ER'

# %%
## We apply the filter

HealthCareDataSet[ERFilter]
# Out:
#            Id MemberName  MemberID    County      MedicalClaim  ClaimItem  \
# 0      634363   e659f3f4  6a380a28  6f943458  c1e3436737c77899         18
# 1      634364   e659f3f4  6a380a28  6f943458  c1e3436737c77899         21
# 2      634387   e659f3f4  6a380a28  6f943458  c1e3436737c77899         10
# 3      634388   e659f3f4  6a380a28  6f943458  c1e3436737c77899         20
# 4      634389   e659f3f4  6a380a28  6f943458  c1e3436737c77899         19
# ...       ...        ...       ...       ...               ...        ...
# 52486  741526   d04bce31  f743344d  02af982d  f9f6df65b12ceb9b         30
# 52487  741527   d04bce31  f743344d  02af982d  f9f6df65b12ceb9b         11
# 52547  741683   c8cec3a7  2abd284d  ea48569b  639b490459f88576          1
# 52548  741684   c8cec3a7  2abd284d  ea48569b  639b490459f88576          3
# 52549  741685   c8cec3a7  2abd284d  ea48569b  639b490459f88576          4
#
#       HospitalName HospitalType  StartDate    EndDate  \
# 0         04b77561     HOSPITAL 2020-01-08 2020-01-08
# 1         04b77561     HOSPITAL 2020-01-08 2020-01-08
# 2         04b77561     HOSPITAL 2020-01-08 2020-01-08
# 3         04b77561     HOSPITAL 2020-01-08 2020-01-08
# 4         04b77561     HOSPITAL 2020-01-08 2020-01-08
# ...            ...          ...        ...        ...
# 52486     446442f4     HOSPITAL 2020-12-16 2020-12-17
# 52487     446442f4     HOSPITAL 2020-12-16 2020-12-17
# 52547     761ae146     HOSPITAL 2020-12-28 2020-12-28
# 52548     761ae146     HOSPITAL 2020-12-28 2020-12-28
# 52549     761ae146     HOSPITAL 2020-12-28 2020-12-28
#
#           PrincipalDiagnosisDesc PrincipalDiagnosis  \
# 0                Epigastric pain             R10.13
# 1                Epigastric pain             R10.13
# 2                Epigastric pain             R10.13
# 3                Epigastric pain             R10.13
# 4                Epigastric pain             R10.13
# ...                          ...                ...
# 52486  Gastritis unspecified wit             K29.70
# 52487  Gastritis unspecified wit             K29.70
# 52547   Constipation unspecified             K59.00
# 52548   Constipation unspecified             K59.00
# 52549   Constipation unspecified             K59.00
#
#                                          RevenueCodeDesc  RevenueCode  \
# 0      DRUGS REQUIRE SPECIFIC ID: DRUGS REQUIRING DET...        636.0
# 1      DRUGS REQUIRE SPECIFIC ID: DRUGS REQUIRING DET...        636.0
# 2           LABORATORY - CLINICAL DIAGNOSTIC: HEMATOLOGY        305.0
# 3      DRUGS REQUIRE SPECIFIC ID: DRUGS REQUIRING DET...        636.0
# 4      DRUGS REQUIRE SPECIFIC ID: DRUGS REQUIRING DET...        636.0
# ...                                                  ...          ...
# 52486                                         ANESTHESIA        370.0
# 52487        LABORATORY - CLINICAL DIAGNOSTIC: CHEMISTRY        301.0
# 52547        LABORATORY - CLINICAL DIAGNOSTIC: CHEMISTRY        301.0
# 52548        LABORATORY - CLINICAL DIAGNOSTIC: CHEMISTRY        301.0
# 52549       LABORATORY - CLINICAL DIAGNOSTIC: HEMATOLOGY        305.0
#
#       TypeFlag  BirthDate  TotalExpenses
# 0           ER 1967-05-13         15.148
# 1           ER 1967-05-13          3.073
# 2           ER 1967-05-13        123.900
# 3           ER 1967-05-13          7.511
# 4           ER 1967-05-13          8.631
# ...        ...        ...            ...
# 52486       ER 1944-11-29       4411.925
# 52487       ER 1944-11-29        747.117
# 52547       ER 1941-07-07         64.295
# 52548       ER 1941-07-07         29.225
# 52549       ER 1941-07-07         40.915
#
# [23978 rows x 17 columns]

# %% [markdown]
# ### Let's select medical events in which the patient's birthdate was higher than 1975.
#
# #### For this we need to perform a filtering operation. We filter on the columm `BirthDate`.

# %%
## We define the filter
HealthCareDataSet['BirthDate']>'1975-01-01'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 52558    False
# 52559    False
# 52560    False
# 52561    False
# 52562    False
# Name: BirthDate, Length: 52563, dtype: bool

# %%
## We save the filter
BirthDateFilter=HealthCareDataSet['BirthDate']>'1975-01-01'

# %%
## We apply the filter
HealthCareDataSet[BirthDateFilter]
# Out:
#            Id MemberName  MemberID    County      MedicalClaim  ClaimItem  \
# 69     634487   89b6abdc  222a11a1  b021dd12  e3678501da0b8833          1
# 74     634522   89b6abdc  222a11a1  b021dd12  e3678501da0b8833          2
# 1455   636578   85e2dc72  c7be7c19  b021dd12  3e347cb83a1d0024         17
# 1456   636579   85e2dc72  c7be7c19  b021dd12  3e347cb83a1d0024          7
# 1457   636580   85e2dc72  c7be7c19  b021dd12  b1f4489a9b0f7345          5
# ...       ...        ...       ...       ...               ...        ...
# 51694  739467   91787cad  58e5143c  89e38653  c9718013c720d0c6          9
# 51695  739468   91787cad  58e5143c  89e38653  c9718013c720d0c6         10
# 51696  739469   91787cad  58e5143c  89e38653  c9718013c720d0c6          4
# 51697  739470   91787cad  58e5143c  89e38653  c9718013c720d0c6          1
# 51698  739471   91787cad  58e5143c  89e38653  c9718013c720d0c6         19
#
#       HospitalName HospitalType  StartDate    EndDate  \
# 69        46658edc     HOSPITAL 2020-01-03 2020-01-03
# 74        46658edc     HOSPITAL 2020-01-03 2020-01-03
# 1455      35da0521     HOSPITAL 2020-01-05 2020-01-05
# 1456      35da0521     HOSPITAL 2020-01-05 2020-01-05
# 1457      4a2b1885     HOSPITAL 2020-01-11 2020-01-12
# ...            ...          ...        ...        ...
# 51694     4b40cef6     HOSPITAL 2020-12-18 2020-12-18
# 51695     4b40cef6     HOSPITAL 2020-12-18 2020-12-18
# 51696     4b40cef6     HOSPITAL 2020-12-18 2020-12-18
# 51697     4b40cef6     HOSPITAL 2020-12-18 2020-12-18
# 51698     4b40cef6     HOSPITAL 2020-12-18 2020-12-18
#
#           PrincipalDiagnosisDesc PrincipalDiagnosis  \
# 69     Other specified disorders             K08.89
# 74     Other specified disorders             K08.89
# 1455          Other muscle spasm            M62.838
# 1456          Other muscle spasm            M62.838
# 1457   Major depressive disorder              F33.3
# ...                          ...                ...
# 51694   Pelvic and perineal pain              R10.2
# 51695   Pelvic and perineal pain              R10.2
# 51696   Pelvic and perineal pain              R10.2
# 51697   Pelvic and perineal pain              R10.2
# 51698   Pelvic and perineal pain              R10.2
#
#                                          RevenueCodeDesc  RevenueCode  \
# 69                                        EMERGENCY ROOM        450.0
# 74     DRUGS REQUIRE SPECIFIC ID: DRUGS REQUIRING DET...        636.0
# 1455   DRUGS REQUIRE SPECIFIC ID: DRUGS REQUIRING DET...        636.0
# 1456         LABORATORY - CLINICAL DIAGNOSTIC: CHEMISTRY        301.0
# 1457         LABORATORY - CLINICAL DIAGNOSTIC: CHEMISTRY        301.0
# ...                                                  ...          ...
# 51694       LABORATORY - CLINICAL DIAGNOSTIC: HEMATOLOGY        305.0
# 51695          LABORATORY - CLINICAL DIAGNOSTIC: UROLOGY        307.0
# 51696                                         IV THERAPY        260.0
# 51697                                           PHARMACY        250.0
# 51698  DRUGS REQUIRE SPECIFIC ID: DRUGS REQUIRING DET...        636.0
#
#       TypeFlag  BirthDate  TotalExpenses
# 69          ER 1986-02-24       1498.700
# 74          ER 1986-02-24         35.700
# 1455        ER 1990-08-22        104.713
# 1456        ER 1990-08-22        557.746
# 1457        ER 1990-08-22         14.700
# ...        ...        ...            ...
# 51694       ER 1986-05-27        108.080
# 51695       ER 1986-05-27        122.129
# 51696       ER 1986-05-27        386.218
# 51697       ER 1986-05-27         31.297
# 51698       ER 1986-05-27         39.508
#
# [1877 rows x 17 columns]

# %% [markdown]
# ### Let's select medical events in which the principal diagnosis is A09
#
# #### For this we need to perform a filtering operation. We filter on the columm `PrincipalDiagnosis`, selecting values equal to A09

# %%
## we define the filter
HealthCareDataSet['PrincipalDiagnosis']=='A09'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
#
# 8711        ER 1947-03-14       1210.363
# ...        ...        ...            ...
# 49735      INP 1951-11-18        765.800
# 49736      INP 1951-11-18        253.225
# 49737      INP 1951-11-18       7495.950
# 49738      INP 1951-11-18        443.100
# 49739      INP 1951-11-18      12843.600
#
# [71 rows x 17 columns]

# %% [markdown]
# ### Let's select medical events in which the principal diagnosis is A09 and took place in emergency room services
#
# #### For this we need to perform a filtering operation. We: (1) filter on the columm `PrincipalDiagnosis`, selecting values equal to A09 and (2) filter on the column `TypeFlag`

# %%
## we define the filter
(HealthCareDataSet['PrincipalDiagnosis']=='A09') & (HealthCareDataSet['TypeFlag']=='ER')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 52558    False
# 52559    False
# 52560    False
# 52561    False
# 52562    False
# Length: 52563, dtype: bool

# %%
## we save the filter
ComplexFilter=(HealthCareDataSet['PrincipalDiagnosis']=='A09') & (HealthCareDataSet['TypeFlag']=='ER')

# %%
## we apply the filter
HealthCareDataSet[ComplexFilter]
# Out:
#           Id MemberName  MemberID    County      MedicalClaim  ClaimItem  \
# 8703  650503   1cdff80e  8ad0f672  02af982d  79c73cbc429daf6a         17
# 8704  650504   1cdff80e  8ad0f672  02af982d  79c73cbc429daf6a          4
# 8705  650507   1cdff80e  8ad0f672  02af982d  79c73cbc429daf6a         10
# 8706  650513   1cdff80e  8ad0f672  02af982d  79c73cbc429daf6a         15
# 8711  650518   1cdff80e  8ad0f672  02af982d  79c73cbc429daf6a          1
# 8712  650519   1cdff80e  8ad0f672  02af982d  79c73cbc429daf6a         14
# 8716  650539   1cdff80e  8ad0f672  02af982d  79c73cbc429daf6a          9
# 8724  650596   1cdff80e  8ad0f672  02af982d  79c73cbc429daf6a          8
# 8725  650597   1cdff80e  8ad0f672  02af982d  79c73cbc429daf6a         13
# 8729  650605   1cdff80e  8ad0f672  02af982d  79c73cbc429daf6a         16
# 8747  650666   1cdff80e  8ad0f672  02af982d  79c73cbc429daf6a         11
# 8748  650667   1cdff80e  8ad0f672  02af982d  79c73cbc429daf6a          2
# 8749  650668   1cdff80e  8ad0f672  02af982d  79c73cbc429daf6a          3
# 8750  650669   1cdff80e  8ad0f672  02af982d  79c73cbc429daf6a          5
# 8751  650670   1cdff80e  8ad0f672  02af982d  79c73cbc429daf6a          6
# 8752  650671   1cdff80e  8ad0f672  02af982d  79c73cbc429daf6a         12
# 8753  650672   1cdff80e  8ad0f672  02af982d  79c73cbc429daf6a          7
#
#      HospitalName HospitalType  StartDate    EndDate  \
# 8703     ae46acbf     HOSPITAL 2020-02-07 2020-02-07
# 8704     ae46acbf     HOSPITAL 2020-02-07 2020-02-07
# 8705     ae46acbf     HOSPITAL 2020-02-07 2020-02-07
# 8706     ae46acbf     HOSPITAL 2020-02-07 2020-02-07
# 8711     ae46acbf     HOSPITAL 2020-02-07 2020-02-07
# 8712     ae46acbf     HOSPITAL 2020-02-07 2020-02-07
# 8716     ae46acbf     HOSPITAL 2020-02-07 2020-02-07
# 8724     ae46acbf     HOSPITAL 2020-02-07 2020-02-07
# 8725     ae46acbf     HOSPITAL 2020-02-07 2020-02-07
# 8729     ae46acbf     HOSPITAL 2020-02-07 2020-02-07
# 8747     ae46acbf     HOSPITAL 2020-02-07 2020-02-07
